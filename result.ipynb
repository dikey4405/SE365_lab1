# %%
# !git clone https://github.com/dikey4405/SE365_lab1.git
# Out:
# Cloning into 'SE365_lab1'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 32 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 14.38 KiB | 4.79 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd SE365_lab1
# Out:
# /kaggle/working/SE365_lab1

# %%
import sys
import os

sys.path.append("/kaggle/working") 

import main
import importlib
importlib.reload(main)

if __name__ == "__main__":
    main.main()
# Out:
# ...
# STARTING: Exp0_Baseline_v1
# ...
# Random seed set to 42
# --- Running Exp: Exp0_Baseline_v1 on cuda ---
# Data chưa có tại /kaggle/working/data/PetImages. Đang tìm kiếm nguồn...
# --> Tìm thấy dataset tại Kaggle Input: /kaggle/input/se365-lab1/PetImages
# --> Đang copy sang /kaggle/working để có quyền ghi/xóa (mất khoảng 1-2 phút)...
# Đang kiểm tra và xóa ảnh lỗi trong /kaggle/working/data/PetImages...
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Hoàn tất. Đã xóa 0 ảnh lỗi.
# Epoch 01 | T_Loss: 0.5692 T_Acc: 0.6941 | V_Loss: 0.4859 V_Acc: 0.7687 | Time: 64.3s
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Epoch 02 | T_Loss: 0.4558 T_Acc: 0.7889 | V_Loss: 0.4458 V_Acc: 0.7967 | Time: 65.1s
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
# ...
